# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
sys.path.append(os.path.abspath('..')) 

import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
from IPython.display import HTML, display
from acpype.topol import ACTopol, MolTopol
import param_tool as pt
# import py3Dmol
import MDAnalysis as mda

import nglview as nv
from parmed import amber, gromacs


IPythonConsole.ipython_useSVG = True
IPythonConsole.molSize = (600, 400)

# %% [markdown]
# ##  Генерация фаила топологии (.itp) при помощи библиотеки acpype
# *Важный момент: acpype готов принимать в себя только единичные остатки аминокислот. При попытке параметризовать ди-/три-/поли-мер выводит следующие ошибки:*\
# `ERROR: more than one residue detected '{'UNK', 'GLY'}'` \
# `ERROR: verify your input file 'GRG_CITsmi.mol2'. Aborting ...`\
# `ERROR: Only ONE Residue is allowed for ACPYPE to work`

# %% [markdown]
# ### Наборы молекул для параметризации

# %% [markdown]
# #### SMI polymer

# %%
def path_dict(path_list):
    mol_dict = {} 
    if isinstance(path_list, str):
        name = os.path.basename(path_list).split('.')[0]
        mol_dict[name] = path_list
    if isinstance(path_list, list):
        for path in path_list:
            name = os.path.basename(path).split('.')[0]
            mol_dict[name] = path
    return mol_dict

# %%
mol_dict = path_dict(['moleculse/RA_CIT.smiles',
                      'moleculse/GRG_CIT.smiles',
                      'moleculse/GR_CIT.smiles'])
smi_dict = pt.read_file(mol_dict)
smi_dict
# Out:
# {'RA_CIT': '[H]N([H])C(=O)N([H])C([H])([H])C([H])([H])C([H])([H])[C@]([H])(C(=O)N([H])C([H])(C([O-])=O)C([H])([H])[H])[N+]([H])([H])[H]',
#  'GRG_CIT': '[H]N([H])C(=O)N([H])C([H])([H])C([H])([H])C([H])([H])C([H])(N([H])C(=O)C([H])([H])[N+]([H])([H])[H])C(=O)N([H])C([H])([H])C([O-])=O',
#  'GR_CIT': '[H]N([H])C(=O)N([H])C([H])([H])C([H])([H])C([H])([H])[C@]([H])(N([H])C(=O)C([H])([H])[N+]([H])([H])[H])C([O-])=O'}

# %% [markdown]
# #### MOL substructure

# %%
os.chdir('/home/_shared/_projects/2022_md_FRET_nv/param_R_CIT')

# %% [markdown]
# ## Использование acpype

# %% [markdown]
# ### SMI

# %%
PTM_folder = 'Lysine_1M'

# %%
# !pwd
# Out:
# /trinity/home/_shared/_projects/2022_md_FRET_nv/AI_param_tool/notebooks_and_examples/AF_546_cys/Acpype_data

# %%
os.chdir(f'/trinity/home/_shared/_projects/2022_md_FRET_nv/AI_param_tool/notebooks_and_examples/AF_546_cys')

# %%
test_smi = pt.read_file([f'molecules/C_AF_546.smiles',
              # 'moleculse/substructure/R_CIT.smiles',
              # 'moleculse/substructure/CR_CIT.smiles'
                        ])
test_chem = pt.smi_to_chem(test_smi, addH=False, sanitize=False)
IPythonConsole.drawOptions.addAtomIndices = True

# %%
pt.draw_mol_with_atom_index(test_chem['C_AF_546'])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=600x400>

# %%
def renumber_atoms(mol):
    for atom in mol.GetAtoms():
        atom.SetProp('molAtomMapNumber', str(int(atom.GetIdx()) + 1))
    return mol

# %%
renum_test_chem = {name: renumber_atoms(mol) for name, mol in test_chem.items()}

# %%
IPythonConsole.drawOptions.addAtomIndices = False
renum_test_chem[PTM_folder]

# %%
chem_dict = pt.smi_to_chem(smi_dict, sanitize=False, addH=True)
chem_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 chem_dict = pt.smi_to_chem(smi_dict, sanitize=False, addH=True)
#       2 chem_dict
#
# NameError: name 'smi_dict' is not defined

# %%
chem_dict['NR_CIT'].GetNumAtoms()
# Out:
# 25

# %% [markdown]
# #### SMI ACTopol

# %%
# os.makedirs('Acpype_data', exist_ok=True)

# %%
os.chdir('Acpype_data/')

# %%
test_smi['C_AF_546']
# Out:
# '[H]OC(=O)C1=C(C(Cl)=C(SC([H])([H])C(=O)N([H])C([H])([H])C([H])([H])C([H])([H])C([H])([H])C([H])([H])C(=O)ON2C(=O)C([H])([H])C([H])(SC([H])([H])C([H])(N([H])[H])C(=O)O[H])C2=O)C(Cl)=C1Cl)C1=C2C([H])=C3C(=NC(C([H])([H])[H])(C([H])([H])[H])C([H])([H])C3([H])C([H])([H])[H])C(=C2OC2=C1C([H])=C1C(N([H])C(C([H])([H])[H])(C([H])([H])[H])C([H])([H])C1([H])C([H])([H])[H])=C2S([O-])(=O)=O)S([O-])(=O)=O'

# %%
molecule = ACTopol(inputFile=test_smi['C_AF_546'], 
                   chargeType="gas", 
                   atomType='amber', 
                   outTopol='gmx',
                   basename=f'C_AF_546_smi', 
                   chargeVal=-2, 
                      )

molecule.createACTopol()
molecule.createMolTopol()
# Out:
# WARNING: In C_AF_546_smi_AC.lib, residue name will be 'MOL' instead of '<1>' elsewhere
# ==> ... charge set to -2
# ==> Executing Antechamber...
# ==> * Antechamber OK *
# ==> * Parmchk OK *
# ==> Executing Tleap...
# ERROR: ++++++++++start_quote+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ERROR: -I: Adding /trinity/home/n_kristovsky/.conda/envs/d_topol/dat/leap/prep to search path.
# -I: Adding /trinity/home/n_kristovsky/.conda/envs/d_topol/dat/leap/lib to search path.
# -I: Adding /trinity/home/n_kristovsky/.conda/envs/d_topol/dat/leap/parm to search path.
# -I: Adding /trinity/home/n_kristovsky/.conda/envs/d_topol/dat/leap/cmd to search path.
# -f: Source tleap.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./tleap.in
# ----- Source: /trinity/home/n_kristovsky/.conda/envs/d_topol/dat/leap/cmd/leaprc.protein.ff14SB
# ----- Source of /trinity/home/n_kristovsky/.conda/envs/d_topol/dat/leap/cmd/leaprc.protein.ff14SB done
# Log file: ./leap.log
# Loading parameters: /trinity/home/n_kristovsky/.conda/envs/d_topol/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /trinity/home/n_kristovsky/.conda/envs/d_topol/dat/leap/parm/frcmod.ff14SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff14SB protein backbone and sidechain parameters
# Loading library: /trinity/home/n_kristovsky/.conda/envs/d_topol/dat/leap/lib/amino12.lib
# Loading: ALA
# Loading: ARG
# Loading: ASH
# Loading: ASN
# Loading: ASP
# Loading: CYM
# Loading: CYS
# Loading: CYX
# Loading: GLH
# Loading: GLN
# Loading: GLU
# Loading: GLY
# Loading: HID
# Loading: HIE
# Loading: HIP
# Loading: HYP
# Loading: ILE
# Loading: LEU
# Loading: LYN
# Loading: LYS
# Loading: MET
# Loading: PHE
# Loading: PRO
# Loading: SER
# Loading: THR
# Loading: TRP
# Loading: TYR
# Loading: VAL
# Loading library: /trinity/home/n_kristovsky/.conda/envs/d_topol/dat/leap/lib/aminoct12.lib
# Loading: CALA
# Loading: CARG
# Loading: CASN
# Loading: CASP
# Loading: CCYS
# Loading: CCYX
# Loading: CGLN
# Loading: CGLU
# Loading: CGLY
# Loading: CHID
# Loading: CHIE
# Loading: CHIP
# Loading: CHYP
# Loading: CILE
# Loading: CLEU
# Loading: CLYS
# Loading: CMET
# Loading: CPHE
# Loading: CPRO
# Loading: CSER
# Loading: CTHR
# Loading: CTRP
# Loading: CTYR
# Loading: CVAL
# Loading: NHE
# Loading: NME
# Loading library: /trinity/home/n_kristovsky/.conda/envs/d_topol/dat/leap/lib/aminont12.lib
# Loading: ACE
# Loading: NALA
# Loading: NARG
# Loading: NASN
# Loading: NASP
# Loading: NCYS
# Loading: NCYX
# Loading: NGLN
# Loading: NGLU
# Loading: NGLY
# Loading: NHID
# Loading: NHIE
# Loading: NHIP
# Loading: NILE
# Loading: NLEU
# Loading: NLYS
# Loading: NMET
# Loading: NPHE
# Loading: NPRO
# Loading: NSER
# Loading: NTHR
# Loading: NTRP
# Loading: NTYR
# Loading: NVAL
# ----- Source: /trinity/home/n_kristovsky/.conda/envs/d_topol/dat/leap/cmd/leaprc.gaff
# ----- Source of /trinity/home/n_kristovsky/.conda/envs/d_topol/dat/leap/cmd/leaprc.gaff done
# Log file: ./leap.log
# Loading parameters: /trinity/home/n_kristovsky/.conda/envs/d_topol/dat/leap/parm/gaff.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 1.81, May 2017)
# Loading parameters: ./C_AF_546_smi_AC.frcmod
# Reading title:
# Loading Mol2 file: ./C_AF_546_smi_gas_amber.mol2
# Reading MOLECULE named *****
# Checking 'MOL'....
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Warning!
# Close contact of 1.447 angstroms between nonbonded atoms H45 and H46
# ------- .R<<1> 1>.A<H45 109> and .R<<1> 1>.A<H46 110>
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Warning!
# Close contact of 1.134 angstroms between nonbonded atoms H48 and H50
# ------- .R<<1> 1>.A<H48 114> and .R<<1> 1>.A<H50 116>
# Checking parameters for unit 'MOL'.
# Checking for bond parameters.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find bond parameter for atom types: CA - S
#  for atom C5 at position 7.107000, 0.407000, 1.122000
#  and atom S1 at position 8.925000, 0.314000, 1.173000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find bond parameter for atom types: OS - N
#  for atom O5 at position 19.081000, 3.846000, -5.556000
#  and atom N2 at position 19.561000, 4.519000, -6.699000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find bond parameter for atom types: CA - DU
#  for atom C27 at position 4.457000, 1.011000, -4.843000
#  and atom N4 at position 4.876000, 0.674000, -5.998000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find bond parameter for atom types: DU - CT
#  for atom N4 at position 4.876000, 0.674000, -5.998000
#  and atom C28 at position 4.250000, 0.658000, -7.173000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find bond parameter for atom types: CA - SO
#  for atom C34 at position 3.590000, 2.058000, -4.585000
#  and atom S4 at position 2.784000, 3.262000, -5.765000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find bond parameter for atom types: CA - OS
#  for atom C35 at position 3.611000, 2.215000, -3.278000
#  and atom O10 at position 2.963000, 3.327000, -2.932000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find bond parameter for atom types: OS - CA
#  for atom O10 at position 2.963000, 3.327000, -2.932000
#  and atom C36 at position 2.770000, 3.667000, -1.682000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find bond parameter for atom types: CA - NT
#  for atom C40 at position 1.565000, 5.080000, -0.243000
#  and atom N5 at position 0.565000, 5.859000, 0.384000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find bond parameter for atom types: CA - SO
#  for atom C47 at position 1.877000, 4.749000, -1.500000
#  and atom S3 at position 1.263000, 5.780000, -2.822000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find bond parameter for atom types: SO - O
#  for atom S3 at position 1.263000, 5.780000, -2.822000
#  and atom O11 at position 2.477000, 6.226000, -3.507000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find bond parameter for atom types: SO - O
#  for atom S3 at position 1.263000, 5.780000, -2.822000
#  and atom O12 at position 0.274000, 4.877000, -3.403000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find bond parameter for atom types: SO - O
#  for atom S3 at position 1.263000, 5.780000, -2.822000
#  and atom O13 at position 0.642000, 6.906000, -2.107000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find bond parameter for atom types: SO - O
#  for atom S4 at position 2.784000, 3.262000, -5.765000
#  and atom O14 at position 3.798000, 3.913000, -6.593000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find bond parameter for atom types: SO - O
#  for atom S4 at position 2.784000, 3.262000, -5.765000
#  and atom O15 at position 1.773000, 2.552000, -6.546000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find bond parameter for atom types: SO - O
#  for atom S4 at position 2.784000, 3.262000, -5.765000
#  and atom O16 at position 2.130000, 4.234000, -4.955000.
# Checking for angle parameters.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: O - C - CA
#  for atom O2 at position 2.062000, 0.673000, 2.182000,
#  atom C1 at position 2.724000, 0.352000, 1.213000,
#  and atom C2 at position 4.220000, 0.316000, 1.158000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: CA - CA - S
#  for atom C4 at position 6.342000, 1.031000, 0.119000,
#  atom C5 at position 7.107000, 0.407000, 1.122000,
#  and atom S1 at position 8.925000, 0.314000, 1.173000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: CA - S - CT
#  for atom C5 at position 7.107000, 0.407000, 1.122000,
#  atom S1 at position 8.925000, 0.314000, 1.173000,
#  and atom C6 at position 9.605000, 1.135000, -0.325000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: S - CA - CA
#  for atom S1 at position 8.925000, 0.314000, 1.173000,
#  atom C5 at position 7.107000, 0.407000, 1.122000,
#  and atom C21 at position 6.379000, -0.208000, 2.189000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: S - CT - C
#  for atom S1 at position 8.925000, 0.314000, 1.173000,
#  atom C6 at position 9.605000, 1.135000, -0.325000,
#  and atom C7 at position 11.121000, 1.086000, -0.348000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: C - OS - N
#  for atom C13 at position 17.716000, 3.764000, -5.438000,
#  atom O5 at position 19.081000, 3.846000, -5.556000,
#  and atom N2 at position 19.561000, 4.519000, -6.699000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: OS - N - C
#  for atom O5 at position 19.081000, 3.846000, -5.556000,
#  atom N2 at position 19.561000, 4.519000, -6.699000,
#  and atom C14 at position 19.139000, 5.733000, -7.133000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: OS - N - C
#  for atom O5 at position 19.081000, 3.846000, -5.556000,
#  atom N2 at position 19.561000, 4.519000, -6.699000,
#  and atom C20 at position 20.655000, 4.048000, -7.365000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: C - N - C
#  for atom C14 at position 19.139000, 5.733000, -7.133000,
#  atom N2 at position 19.561000, 4.519000, -6.699000,
#  and atom C20 at position 20.655000, 4.048000, -7.365000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: S - CT - C
#  for atom S2 at position 22.765000, 5.743000, -7.796000,
#  atom C16 at position 21.114000, 5.125000, -8.356000,
#  and atom C20 at position 20.655000, 4.048000, -7.365000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: NT - CT - C
#  for atom N3 at position 25.620000, 6.567000, -8.742000,
#  atom C18 at position 24.583000, 7.628000, -8.728000,
#  and atom C19 at position 24.953000, 8.730000, -9.729000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: CA - CA - OS
#  for atom C24 at position 4.308000, 1.328000, -2.284000,
#  atom C35 at position 3.611000, 2.215000, -3.278000,
#  and atom O10 at position 2.963000, 3.327000, -2.932000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: CA - CA - DU
#  for atom C26 at position 5.091000, -0.096000, -4.133000,
#  atom C27 at position 4.457000, 1.011000, -4.843000,
#  and atom N4 at position 4.876000, 0.674000, -5.998000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: CA - DU - CT
#  for atom C27 at position 4.457000, 1.011000, -4.843000,
#  atom N4 at position 4.876000, 0.674000, -5.998000,
#  and atom C28 at position 4.250000, 0.658000, -7.173000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: CA - CA - SO
#  for atom C27 at position 4.457000, 1.011000, -4.843000,
#  atom C34 at position 3.590000, 2.058000, -4.585000,
#  and atom S4 at position 2.784000, 3.262000, -5.765000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: DU - CA - CA
#  for atom N4 at position 4.876000, 0.674000, -5.998000,
#  atom C27 at position 4.457000, 1.011000, -4.843000,
#  and atom C34 at position 3.590000, 2.058000, -4.585000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: DU - CT - CT
#  for atom N4 at position 4.876000, 0.674000, -5.998000,
#  atom C28 at position 4.250000, 0.658000, -7.173000,
#  and atom C29 at position 2.755000, 0.424000, -7.142000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: DU - CT - CT
#  for atom N4 at position 4.876000, 0.674000, -5.998000,
#  atom C28 at position 4.250000, 0.658000, -7.173000,
#  and atom C30 at position 5.044000, 1.924000, -7.563000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: DU - CT - CT
#  for atom N4 at position 4.876000, 0.674000, -5.998000,
#  atom C28 at position 4.250000, 0.658000, -7.173000,
#  and atom C31 at position 4.797000, -0.747000, -7.158000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: CA - CA - OS
#  for atom C34 at position 3.590000, 2.058000, -4.585000,
#  atom C35 at position 3.611000, 2.215000, -3.278000,
#  and atom O10 at position 2.963000, 3.327000, -2.932000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: CA - SO - O
#  for atom C34 at position 3.590000, 2.058000, -4.585000,
#  atom S4 at position 2.784000, 3.262000, -5.765000,
#  and atom O14 at position 3.798000, 3.913000, -6.593000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: CA - SO - O
#  for atom C34 at position 3.590000, 2.058000, -4.585000,
#  atom S4 at position 2.784000, 3.262000, -5.765000,
#  and atom O15 at position 1.773000, 2.552000, -6.546000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: CA - SO - O
#  for atom C34 at position 3.590000, 2.058000, -4.585000,
#  atom S4 at position 2.784000, 3.262000, -5.765000,
#  and atom O16 at position 2.130000, 4.234000, -4.955000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: CA - CA - SO
#  for atom C35 at position 3.611000, 2.215000, -3.278000,
#  atom C34 at position 3.590000, 2.058000, -4.585000,
#  and atom S4 at position 2.784000, 3.262000, -5.765000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: CA - OS - CA
#  for atom C35 at position 3.611000, 2.215000, -3.278000,
#  atom O10 at position 2.963000, 3.327000, -2.932000,
#  and atom C36 at position 2.770000, 3.667000, -1.682000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: OS - CA - CA
#  for atom O10 at position 2.963000, 3.327000, -2.932000,
#  atom C36 at position 2.770000, 3.667000, -1.682000,
#  and atom C37 at position 3.396000, 2.922000, -0.681000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: OS - CA - CA
#  for atom O10 at position 2.963000, 3.327000, -2.932000,
#  atom C36 at position 2.770000, 3.667000, -1.682000,
#  and atom C47 at position 1.877000, 4.749000, -1.500000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: CA - CA - SO
#  for atom C36 at position 2.770000, 3.667000, -1.682000,
#  atom C47 at position 1.877000, 4.749000, -1.500000,
#  and atom S3 at position 1.263000, 5.780000, -2.822000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: CA - CA - NT
#  for atom C39 at position 2.508000, 4.655000, 0.585000,
#  atom C40 at position 1.565000, 5.080000, -0.243000,
#  and atom N5 at position 0.565000, 5.859000, 0.384000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: CA - NT - H
#  for atom C40 at position 1.565000, 5.080000, -0.243000,
#  atom N5 at position 0.565000, 5.859000, 0.384000,
#  and atom H38 at position 0.458000, 6.568000, -0.431000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: CA - NT - CT
#  for atom C40 at position 1.565000, 5.080000, -0.243000,
#  atom N5 at position 0.565000, 5.859000, 0.384000,
#  and atom C41 at position 0.792000, 6.632000, 2.061000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: CA - CA - SO
#  for atom C40 at position 1.565000, 5.080000, -0.243000,
#  atom C47 at position 1.877000, 4.749000, -1.500000,
#  and atom S3 at position 1.263000, 5.780000, -2.822000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: NT - CA - CA
#  for atom N5 at position 0.565000, 5.859000, 0.384000,
#  atom C40 at position 1.565000, 5.080000, -0.243000,
#  and atom C47 at position 1.877000, 4.749000, -1.500000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: CA - SO - O
#  for atom C47 at position 1.877000, 4.749000, -1.500000,
#  atom S3 at position 1.263000, 5.780000, -2.822000,
#  and atom O11 at position 2.477000, 6.226000, -3.507000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: CA - SO - O
#  for atom C47 at position 1.877000, 4.749000, -1.500000,
#  atom S3 at position 1.263000, 5.780000, -2.822000,
#  and atom O12 at position 0.274000, 4.877000, -3.403000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: CA - SO - O
#  for atom C47 at position 1.877000, 4.749000, -1.500000,
#  atom S3 at position 1.263000, 5.780000, -2.822000,
#  and atom O13 at position 0.642000, 6.906000, -2.107000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: O - SO - O
#  for atom O11 at position 2.477000, 6.226000, -3.507000,
#  atom S3 at position 1.263000, 5.780000, -2.822000,
#  and atom O12 at position 0.274000, 4.877000, -3.403000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: O - SO - O
#  for atom O11 at position 2.477000, 6.226000, -3.507000,
#  atom S3 at position 1.263000, 5.780000, -2.822000,
#  and atom O13 at position 0.642000, 6.906000, -2.107000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: O - SO - O
#  for atom O12 at position 0.274000, 4.877000, -3.403000,
#  atom S3 at position 1.263000, 5.780000, -2.822000,
#  and atom O13 at position 0.642000, 6.906000, -2.107000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: O - SO - O
#  for atom O14 at position 3.798000, 3.913000, -6.593000,
#  atom S4 at position 2.784000, 3.262000, -5.765000,
#  and atom O15 at position 1.773000, 2.552000, -6.546000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: O - SO - O
#  for atom O14 at position 3.798000, 3.913000, -6.593000,
#  atom S4 at position 2.784000, 3.262000, -5.765000,
#  and atom O16 at position 2.130000, 4.234000, -4.955000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# Could not find angle parameter for atom types: O - SO - O
#  for atom O15 at position 1.773000, 2.552000, -6.546000,
#  atom S4 at position 2.784000, 3.262000, -5.765000,
#  and atom O16 at position 2.130000, 4.234000, -4.955000.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Warning!
# There are missing parameters.
# check: Warnings: 2
# Unit is OK.
# Checking Unit.
# Building topology.
# Building atom parameters.
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# For atom (.R<<1> 1>.A<N4 69>) could not find vdW (or other) parameters for type (DU)
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# For atom (.R<<1> 1>.A<S3 118>) could not find vdW (or other) parameters for type (SO)
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Error!
# For atom (.R<<1> 1>.A<S4 122>) could not find vdW (or other) parameters for type (SO)
#
# /trinity/home/n_kristovsky/.conda/envs/d_topol/bin/teLeap: Warning!
# Parameter file was not saved.
#  Creating C_AF_546_smi_AC.lib
# Saving MOL.
# Building topology.
# Building atom parameters.
# 	Quit
#
# Exiting LEaP: Errors = 60; Warnings = 4; Notes = 0.
# ERROR: ++++++++++end_quote+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ERROR: Tleap failed
# ==> Removing temporary files...
# ERROR: Files 'C_AF_546_smi_AC.inpcrd' and/or 'C_AF_546_smi_AC.prmtop' don't exist
# ERROR: molTopol object won't be created
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 10
#       1 molecule = ACTopol(inputFile=test_smi['C_AF_546'],
#       2                    chargeType="gas",
#       3                    atomType='amber',
#    (...)      6                    chargeVal=-2,
#       7                       )
#       9 molecule.createACTopol()
# ---> 10 molecule.createMolTopol()
#
# File ~/.conda/envs/d_topol/lib/python3.12/site-packages/acpype/topol.py:1116, in AbstractTopol.createMolTopol(self)
#    1112 """
#    1113 Create MolTopol obj.
#    1114 """
#    1115 self.topFileData = open(self.acTopFileName).readlines()
# -> 1116 self.molTopol = MolTopol(
#    1117     self,  # acTopolObj
#    1118     verbose=self.verbose,
#    1119     debug=self.debug,
#    1120     gmx4=self.gmx4,
#    1121     merge=self.merge,
#    1122     direct=self.direct,
#    1123     is_sorted=self.sorted,
#    1124     chiral=self.chiral,
#    1125 )
#    1126 if self.outTopols:
#    1127     if "cns" in self.outTopols:
#
# File ~/.conda/envs/d_topol/lib/python3.12/site-packages/acpype/topol.py:3412, in MolTopol.__init__(self, acTopolObj, acFileXyz, acFileTop, debug, basename, verbose, gmx4, merge, direct, is_sorted, chiral, amb2gmx, level)
#    3409     self.printError(f"Files '{acFileXyz}' and/or '{acFileTop}' don't exist")
#    3410     self.printError("molTopol object won't be created")
# -> 3412 self.xyzFileData = open(acFileXyz).readlines()
#    3413 self.topFileData = [x for x in open(acFileTop).readlines() if not x.startswith("%COMMENT")]
#    3414 self.topo14Data = Topology_14()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C_AF_546_smi_AC.inpcrd'

# %% [markdown]
# ### PDB

# %%
# !pwd
# Out:
# /trinity/home/_shared/_projects/2022_md_FRET_nv/AI_param_tool/notebooks_and_examples/AF_546_cys

# %%
PTM_folder = 'C_AF546'

# %%
path = 'molecules/substructure/C_AF546_rn_H_3D.pdb'
param_file = os.path.basename(path)
full_mol_name = param_file.split('.')[0]
print(full_mol_name)
# NR_CIT = RRR.select_atoms('resnum 1')
param_mol = mda.Universe(path)
nv.show_mdanalysis(param_mol)
# NR_CIT
# Out:
# C_AF546_rn_H_3D
# NGLWidget()

# %%
param_chem = pt.pdb_to_chem(path)
param_chem[full_mol_name]

# %%
param_file
# Out:
# 'C_AF546_rn_H_3D.pdb'

# %%
# NR_CIT.write('moleculse/NR_CIT_pdb.pdb')

# %%
# !pwd
# Out:
# /trinity/home/_shared/_projects/2022_md_FRET_nv/AI_param_tool/notebooks_and_examples/AF_546_cys/Acpype_data

# %% [markdown]
# #### PDB ACTopol

# %%
os.chdir(f'/trinity/home/_shared/_projects/2022_md_FRET_nv/AI_param_tool/notebooks_and_examples/AF_546_cys/Acpype_data/')

# %%
from openbabel import pybel

# %%
# def convert_with_names(input_file, output_file, output_format):
#     for mol in pybel.readfile("pdb", input_file):
#         mol.write(output_format, output_file, overwrite=False)

# convert_with_names("molecules.pdb", "molecules.mol2", "mol2")

# %%
# !obabel ../molecules/substructure/{full_mol_name}.pdb -O ../molecules/substructure/{full_mol_name}.mol2 --keepnames
# Out:
# 1 molecule converted

# %%
# molecule = ACTopol(inputFile = f'../molecules/substructure/{param_file}', 
molecule = ACTopol(inputFile = f'../molecules/substructure/{full_mol_name}.mol2', 
                   
                   chargeType="user",  # bcc
                   atomType='gaff2', 
                   outTopol='gmx', 
                   basename=f'{full_mol_name}', 
                   chargeVal=-2, 
                   debug=True
                   )
molecule.createACTopol()
molecule.createMolTopol()
# Out:
# DEBUG: Max execution time tolerance is 3h
# DEBUG: /trinity/home/n_kristovsky/.conda/envs/d_topmol/bin/antechamber -dr no -i C_AF546_rn_H_3D.mol2 -fi mol2 -o tmp -fo ac -pf y
# DEBUG: Info: The atom type is set to gaff; the options available to the -at flag are
#  gaff, gaff2, amber, bcc, abcg2, and sybyl.
#
# Warning: Ignoring Mol2 record type (@<TRIPOS>UNITY_ATOM_ATTR).
#
# DEBUG: Residue name is a 'number': '546'
# WARNING: In C_AF546_rn_H_3D_AC.lib, residue name will be 'R546' instead of '546' elsewhere
# DEBUG: setResNameCheckCoords done
# ==> Reading user's charges from mol2 file...
# DEBUG: /trinity/home/n_kristovsky/.conda/envs/d_topmol/bin/antechamber -dr no -i C_AF546_rn_H_3D.mol2 -fi mol2 -o tmp -fo mol2 -c wc -cf tmp.crg -pf n
# DEBUG: ++++++++++start_quote+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# DEBUG: Info: The atom type is set to gaff; the options available to the -at flag are
#  gaff, gaff2, amber, bcc, abcg2, and sybyl.
#
# Warning: Ignoring Mol2 record type (@<TRIPOS>UNITY_ATOM_ATTR).
#
# DEBUG: ++++++++++end_quote+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# DEBUG: readMol2TotalCharge: -2.0
# DEBUG: Net charge drift '0.000000'
# ==> ... charge set to -2
# ==> Executing Antechamber...
# DEBUG: /trinity/home/n_kristovsky/.conda/envs/d_topmol/bin/antechamber -dr no -i C_AF546_rn_H_3D.mol2 -fi mol2 -o C_AF546_rn_H_3D_user_gaff2.mol2 -fo mol2 -nc -2 -m 1 -s 2 -df 2 -at gaff2 -pf n
# DEBUG: No file left to be removed
# ==> * Antechamber OK *
# DEBUG: /trinity/home/n_kristovsky/.conda/envs/d_topmol/bin/parmchk2 -i C_AF546_rn_H_3D_user_gaff2.mol2 -f mol2 -o C_AF546_rn_H_3D_AC.frcmod -s 2
# ==> * Parmchk OK *
# DEBUG: No crd or prm files left to be removed
# ==> Executing Tleap...
# DEBUG: /trinity/home/n_kristovsky/.conda/envs/d_topmol/bin/tleap -f tleap.in
# DEBUG: ++++++++++start_quote+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# DEBUG: Checking 'R546'....
#
# /trinity/home/n_kristovsky/.conda/envs/d_topmol/bin/teLeap: Warning!
# The unperturbed charge of the unit (-2.000000) is not zero.
# Checking parameters for unit 'R546'.
# Checking for bond parameters.
# Checking for angle parameters.
# check: Warnings: 1
# Unit is OK.
# DEBUG: ++++++++++end_quote+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ==> * Tleap OK *
# DEBUG: prmtop and inpcrd files loaded
# DEBUG: basename defined = 'C_AF546_rn_H_3D'
# DEBUG: getCoords done
# DEBUG: getABCOEFs done
# DEBUG: charge to be balanced: total -2.0000000000
# DEBUG: balanceCharges done
# DEBUG: Balanced TotalCharge -2.0000000000
# DEBUG: PBC = None
# DEBUG: getAtoms done
# DEBUG: getBonds done
# DEBUG: getAngles done
# DEBUG: getDihedrals done
# ==> Using OpenBabel v.3.1.0
#
# ==> Writing GROMACS files
#
# ==> Disambiguating lower and uppercase atomtypes in GMX top file, even if identical.
#
# DEBUG: writing GRO file
# DEBUG: Box size estimated
# DEBUG: writing POSRE file
# DEBUG: atomTypes 22
# DEBUG: GMX atomtypes done
# DEBUG: atoms 124
# DEBUG: GMX atoms done
# DEBUG: bonds 130
# DEBUG: GMX bonds done
# DEBUG: atomPairs 323
# DEBUG: GMX pairs done
# DEBUG: angles 237
# DEBUG: GMX angles done
# DEBUG: setProperDihedralsCoef done
# DEBUG: properDihedralsCoefRB 346
# DEBUG: properDihedralsAlphaGamma 0
# DEBUG: properDihedralsGmx45 374
# ==> Writing GMX dihedrals for GMX 4.5 and higher.
#
# DEBUG: GMX special proper dihedrals done
# DEBUG: improperDihedrals 28
# DEBUG: GMX improper dihedrals done
# ==> Writing pickle file C_AF546_rn_H_3D.pkl

# %%
# !pwd
# Out:
# /trinity/home/_shared/_projects/2022_md_FRET_nv/AI_param_tool/notebooks_and_examples/AF_546_cys/Acpype_data

# %%
os.chdir('../')

# %%
from parmed import amber, gromacs

# %%
top_L = gromacs.GromacsTopologyFile(f'{full_mol_name}.acpype/{full_mol_name}_GMX.itp')
residue = pt.pdb_to_chem(f'../molecules/substructure/{param_file}')
residue
# Out:
# {'C_AF546_rn_H_3D': <rdkit.Chem.rdchem.Mol at 0x15551ad85930>}

# %%
for top_atom, chem_atom in zip(top_L, residue[full_mol_name].GetAtoms()):
    top_atom.name = chem_atom.GetProp('AtomName')
    top_atom.residue.name = '546'

# %%
top_L.save(f'{full_mol_name}.acpype/{full_mol_name}_mod.itp', format='gromacs')

# %% [markdown]
# ## Ручной вариант

# %%
os.chdir('/home/_projects/2022_md_FRET_nv/param_R_CIT/Lysine_1M/Acpype_data/test/')

# %%
# %%bash
#
# antechamber -i ../../molecules/substructure/Lysine_1M_rn_H_3D.pdb -fi pdb -o Lysine_1M_rn_H_3D_gas_amber.mol2 -fo mol2 -c gas -nc 1 -m 1 -s 2 -df 2 -at amber -pf n
# antechamber -i ../../molecules/substructure/Lysine_1M_rn_H_3D.pdb -fi pdb -o Lysine_1M_rn_H_3D_gas_amber.prepin -fo prepi -c gas -j 4 -at gaff
# parmchk2 -i Lysine_1M_rn_H_3D_gas_amber.mol2 -f mol2 -o Lysine_1M_rn_H_3D_AC.frcmod -p /tmp/parm10gaffff14SB.dat
# parmchk -i Lysine_1M_rn_H_3D_AC.prepin -o Lysine_1M_rn_H_3D_AC.frcmod -f prepi -p /tmp/parm10gaffff14SB.dat
# Out:
# Welcome to antechamber 19.0: molecular input file processor.
#
# acdoctor mode is on: check and diagnose problems in the input file.
# -- Check Format for pdb File --
#    Status: pass
# -- Check Unusual Elements --
#    Status: pass
# -- Check Open Valences --
#    Status: pass
# -- Check Geometry --
#       for those bonded
#       for those not bonded
#    Status: pass
# -- Check Weird Bonds --
#    Status: pass
# -- Check Number of Units --
#    Status: pass
# acdoctor mode has completed checking the input file.
#
# Running: /home/n_kristovsky/.conda/envs/topmol2/bin/bondtype -j full -i ANTECHAMBER_BOND_TYPE.AC0 -o ANTECHAMBER_BOND_TYPE.AC -f ac
#
# Running: /home/n_kristovsky/.conda/envs/topmol2/bin/atomtype -i ANTECHAMBER_AC.AC0 -o ANTECHAMBER_AC.AC -p amber
# Running: /home/n_kristovsky/.conda/envs/topmol2/bin/atomtype -i ANTECHAMBER_GAS.AC -o ANTECHAMBER_GAS_AT.AC -d /home/n_kristovsky/.conda/envs/topmol2/dat/antechamber/ATOMTYPE_GAS.DEF

# %%
# %%bash
#
# antechamber -i ../../molecules/substructure/Lysine_1M_rn_H_3D.pdb -fi pdb -o Lysine_1M_rn_H_3D_gas_amber.prepin -fo prepi -c gas -j 4 -nc 1 -m 1 -s 2 -df 2 -at amber -pf n
# # antechamber -i ../../molecules/substructure/Lysine_1M_rn_H_3D.pdb -fi pdb -o Lysine_1M_rn_H_3D_gas_amber.prepin -fo prepi -c gas -j 4 -at gaff
# # parmchk2 -i Lysine_1M_rn_H_3D_gas_amber.mol2 -f mol2 -o Lysine_1M_rn_H_3D_AC.frcmod -p /tmp/parm10gaffff14SB.dat

# %%
# %%bash
# parmchk2 -i Lysine_1M_rn_H_3D_gas_amber.prepin -o Lysine_1M_rn_H_3D_gas_amber.frcmod -f prepi -p /tmp/parm10gaffff14SB.dat

# %%
molecule.execParmchk()
# Out:
# ERROR: ++++++++++start_quote+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ERROR: Cannot open file (Lysine_1M_rn_H_3D_gas_amber.mol2) with mode (r).
# No such file or directory
# ERROR: ++++++++++end_quote+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# True

# %%
molecule.createMolTopol()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 molecule.createMolTopol()
#
# File ~/.conda/envs/topmol2/lib/python3.8/site-packages/acpype/topol.py:1116, in AbstractTopol.createMolTopol(self)
#    1112 def createMolTopol(self):
#    1113     """
#    1114     Create MolTopol obj.
#    1115     """
# -> 1116     self.topFileData = open(self.acTopFileName).readlines()
#    1117     self.molTopol = MolTopol(
#    1118         self,  # acTopolObj
#    1119         verbose=self.verbose,
#    (...)
#    1125         chiral=self.chiral,
#    1126     )
#    1127     if self.outTopols:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Lysine_1M_rn_H_3D_AC.prmtop'

# %%
# !pwd
# Out:
# /home/_shared/_projects/2022_md_FRET_nv/param_R_CIT

# %%
os.chdir('/home/_projects/2022_md_FRET_nv/param_R_CIT')

# %%
acpype_name = 'Lysin_1M_ACC_rn_H_3D'
top = gromacs.GromacsTopologyFile(f"Acpype_data/{acpype_name}.acpype/{acpype_name}_GMX.itp")

# %%
for a in top.atoms:
    print(a.name, a.atom_type,a.idx)
# Out:
# N NT 0
# CA CT 1
# C C 2
# O O 3
# CB CT 4
# CG CT 5
# CD CT 6
# CE CT 7
# N2 N 8
# C7 C 9
# O2 O 10
# C8 CT 11
# H7 HC 12
# H2 HC 13
# H3 HC 14
# C9 CT 15
# H4 H1 16
# H5 H1 17
# H6 H1 18
# HE2 H1 19
# HE3 H1 20
# HD2 HC 21
# HD3 HC 22
# HG2 HC 23
# HG3 HC 24
# HB2 HC 25
# HB3 HC 26
# HA H1 27
# H1 H 28
# HM H 29
# HM1 HA 30

# %%
for name, mol in smi_dict.items():
# Проверяем существование папки Acpype и создаём её, если нужно

# Путь к файлу MDL, который будет создан

    # molecul = 'mol'
# Создание объекта ACTopol и выполнение методов
    molecule = ACTopol(mol, chargeType="gas", atomType='gaff2', outTopol='gmx',
                       basename=name+'smi', chargeVal=0, 
                       # amb2gmx=True
                      )


    molecule.createACTopol()
    molecule.createMolTopol()
# Out:
# ==> ... charge set to 0
# ==> Executing Antechamber...
# ==> * Antechamber OK *
# ==> * Parmchk OK *
# ==> Executing Tleap...
# ==> * Tleap OK *
# ==> Removing temporary files...
# ==> Using OpenBabel v.3.1.0
#
# ==> Writing GROMACS files
#
# ==> Disambiguating lower and uppercase atomtypes in GMX top file, even if identical.
#
# ==> Writing GMX dihedrals for GMX 4.5 and higher.
#
# ==> Writing pickle file R_CITsmi.pkl
# ==> Removing temporary files...
# ==> ... charge set to 0
# ==> Executing Antechamber...
# ==> * Antechamber OK *
# ==> * Parmchk OK *
# ==> Executing Tleap...
# ==> * Tleap OK *
# ==> Removing temporary files...
# ==> Using OpenBabel v.3.1.0
#
# ==> Writing GROMACS files
#
# ==> Disambiguating lower and uppercase atomtypes in GMX top file, even if identical.
#
# ==> Writing GMX dihedrals for GMX 4.5 and higher.
#
# ==> Writing pickle file NR_CITsmi.pkl
# ==> Removing temporary files...
# ==> ... charge set to 0
# ==> Executing Antechamber...
# ==> * Antechamber OK *
# ==> * Parmchk OK *
# ==> Executing Tleap...
# ==> * Tleap OK *
# ==> Removing temporary files...
# ==> Using OpenBabel v.3.1.0
#
# ==> Writing GROMACS files
#
# ==> Disambiguating lower and uppercase atomtypes in GMX top file, even if identical.
#
# ==> Writing GMX dihedrals for GMX 4.5 and higher.
#
# ==> Writing pickle file CR_CITsmi.pkl
# ==> Removing temporary files...

# %%
os.chdir('/home/_projects/2022_md_FRET_nv/param_R_CIT')

# %%
IPythonConsole.drawOptions.addAtomIndices = True
IPythonConsole.ipython_useSVG = True
IPythonConsole.molSize = (1200, 400)

# %%
mol = Chem.MolFromMolFile('Acpype_data/NR_CIT.acpype/CR_CIT.mol',removeHs=False, sanitize=False)
mol
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 mol = Chem.MolFromMolFile('Acpype_data/NR_CIT.acpype/CR_CIT.mol',removeHs=False, sanitize=False)
#       2 mol
#
# OSError: Bad input file Acpype_data/NR_CIT.acpype/CR_CIT.mol

# %%
mol = Chem.MolFromMolFile('NR_CITmol.acpype/NR_CIT.mol',removeHs=False, sanitize=False)
mol

# %%
R_CIT = pt.smi_to_chem(mol_dict)
R_CIT['R_CIT']
# Out:
# [12:00:45] SMILES Parse Error: syntax error while parsing: moleculse/substructure/R_CIT.smiles
# [12:00:45] SMILES Parse Error: Failed parsing SMILES 'moleculse/substructure/R_CIT.smiles' for input: 'moleculse/substructure/R_CIT.smiles'
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 R_CIT = pt.smi_to_chem(mol_dict)
#       2 R_CIT['R_CIT']
#
# File /home/_shared/_projects/2022_md_FRET_nv/param_R_CIT/param_tool.py:53, in data_to_dict.<locals>.wrapper(data)
#      51     return {get_name(str_data, i):funсtion(str_data) for i, str_data in enumerate(data)}
#      52 elif isinstance(data, dict):
# ---> 53     return {legend: funсtion(str_data) for legend, str_data in data.items()}
#      54 else:
#      55     print('Некорректный тип данных ввода', file=sys.stderr)
#
# File /home/_shared/_projects/2022_md_FRET_nv/param_R_CIT/param_tool.py:53, in <dictcomp>(.0)
#      51     return {get_name(str_data, i):funсtion(str_data) for i, str_data in enumerate(data)}
#      52 elif isinstance(data, dict):
# ---> 53     return {legend: funсtion(str_data) for legend, str_data in data.items()}
#      54 else:
#      55     print('Некорректный тип данных ввода', file=sys.stderr)
#
# File /home/_shared/_projects/2022_md_FRET_nv/param_R_CIT/param_tool.py:92, in smi_to_chem(str_smi)
#      88 """
#      89 Преобразует SMILES-строку в объект молекулы RDKit и добавляет атомы водорода.
#      90 """
#      91 mol_chem = Chem.MolFromSmiles(str_smi) # переводим во внутренний формат chem
# ---> 92 mol_chem = Chem.AddHs(mol_chem) # протонируем
#      93 return mol_chem
#
# ArgumentError: Python argument types in
#     rdkit.Chem.rdmolops.AddHs(NoneType)
# did not match C++ signature:
#     AddHs(RDKit::ROMol mol, bool explicitOnly=False, bool addCoords=False, boost::python::api::object onlyOnAtoms=None, bool addResidueInfo=False)

# %%
# !pwd
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# ERROR: error getting working directory name: no such file or directory
# >/usr/share/modules/init/bash: line 58: export: _moduleraw: not a function
# pwd: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory

# %%
smi_dict = pt.read_file(mol_dict)
smi_dict
chem_dict = {}
for name ,smi in smi_dict.items():
    chem_dict[name] = Chem.MolFromSmiles(smi, sanitize=False)
chem_dict
# mol = pt.smi_to_chem(mol)
# mol['R_CIT']
# Out:
# {'R_CIT': <rdkit.Chem.rdchem.Mol at 0x7f7f32c2de20>,
#  'NR_CIT': <rdkit.Chem.rdchem.Mol at 0x7f7f32c2d880>,
#  'CR_CIT': <rdkit.Chem.rdchem.Mol at 0x7f7f33143e80>}

# %%
chem_dict['CR_CIT']

# %%
def show_mol2(mol2, maxIters=200,  **kwarg):
    mol = Chem.MolFromMol2File(mol2,  **kwarg)
    # if addh:
    #     mol = Chem.AddHs(mol)

    # Оптимизация 3D-структуры 
    AllChem.EmbedMolecule(mol, ignoreSmoothingFailures=True)
    AllChem.MMFFOptimizeMolecule(mol, maxIters=maxIters)
    
    # Создание объекта для 3D-визуализации
    view = py3Dmol.view(width=600, height=400)

    # Добавление модели молекулы
    mblock = Chem.MolToMolBlock(mol)
    view.addModel(mblock, 'mol')

    # Настройка стиля
    view.setStyle({'stick': {}})

    # Масштабирование и отображение
    view.zoomTo()
    view.show()

# %%
def show_mol2(mol2, maxIters=200, **kwarg):
    try:
        with open(mol2, 'r') as f:
            mol2_data = f.read()
        
        # Создаем молекулу без санитизации
        mol = Chem.MolFromMol2Block(mol2_data, sanitize=False, removeHs=kwarg.get('removeHs', True))
        
        if mol is None:
            raise ValueError("Ошибка при чтении файла mol2.")
        
        # Применение минимальных изменений для обеспечения корректной валентности
        for atom in mol.GetAtoms():
            atom.UpdatePropertyCache(strict=False)
            if atom.GetExplicitValence() > atom.GetTotalDegree():
                atom.SetNoImplicit(True)
                atom.UpdatePropertyCache(strict=False)
        
        # Попытка санитизации молекулы после ручной правки валентности с игнорированием ошибок
        try:
            Chem.SanitizeMol(mol, Chem.SanitizeFlags.SANITIZE_ALL ^ Chem.SanitizeFlags.SANITIZE_PROPERTIES)
        except Exception as e:
            print(f"Валентность некоторых атомов остается некорректной: {e}")
        
        # Добавление водородов, если это необходимо
        if kwarg.get('addHs', False):
            mol = Chem.AddHs(mol)

        # Оптимизация 3D-структуры 
        AllChem.EmbedMolecule(mol, ignoreSmoothingFailures=True)
        AllChem.MMFFOptimizeMolecule(mol, maxIters=maxIters)
        
        # Создание объекта для 3D-визуализации
        view = py3Dmol.view(width=600, height=400)

        # Добавление модели молекулы
        mblock = Chem.MolToMolBlock(mol)
        view.addModel(mblock, 'mol')

        # Настройка стиля
        view.setStyle({'stick': {}})

        # Масштабирование и отображение
        view.zoomTo()
        view.show()
    except Exception as e:
        print(f"Ошибка: {e}")
